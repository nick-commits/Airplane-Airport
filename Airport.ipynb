# %%
import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# %%
import numpy as np 
import seaborn as sns 
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = pd.read_csv('Jan_2019_ontime.csv')

# %%
df.head()
# Out:
#    DAY_OF_MONTH  DAY_OF_WEEK OP_UNIQUE_CARRIER  OP_CARRIER_AIRLINE_ID  \
# 0             1            2                9E                  20363
# 1             1            2                9E                  20363
# 2             1            2                9E                  20363
# 3             1            2                9E                  20363
# 4             1            2                9E                  20363
#
#   OP_CARRIER TAIL_NUM  OP_CARRIER_FL_NUM  ORIGIN_AIRPORT_ID  \
# 0         9E   N8688C               3280              11953
# 1         9E   N348PQ               3281              13487
# 2         9E   N8896A               3282              11433
# 3         9E   N8886A               3283              15249
# 4         9E   N8974C               3284              10397
#
#    ORIGIN_AIRPORT_SEQ_ID ORIGIN  ...  DEST  DEP_TIME DEP_DEL15  DEP_TIME_BLK  \
# 0                1195302    GNV  ...   ATL     601.0       0.0     0600-0659
# ...

# %%
ap[ap['id']==11953]
# Out:
#          id ident      type                            name  latitude_deg  \
# 5908  11953  53FL  heliport  University of Florida Heliport       29.6441
#
#       longitude_deg  elevation_ft continent iso_country iso_region  \
# 5908     -82.353203         125.0       NaN          US      US-FL
#
#      municipality scheduled_service gps_code iata_code local_code home_link  \
# 5908  Gainesville                no     53FL       NaN       53FL       NaN
#
#      wikipedia_link keywords
# 5908            NaN      NaN

# %%
ap[ap['iso_country']=='US'].head(20)
# Out:
#         id ident           type                                name  \
# 0     6523   00A       heliport                   Total Rf Heliport
# 1   323361  00AA  small_airport                Aero B Ranch Airport
# 2     6524  00AK  small_airport                        Lowell Field
# 3     6525  00AL  small_airport                        Epps Airpark
# 4     6526  00AR         closed  Newport Hospital & Clinic Heliport
# 5   322127  00AS  small_airport                      Fulton Airport
# 6     6527  00AZ  small_airport                      Cordes Airport
# 7     6528  00CA  small_airport             Goldstone /Gts/ Airport
# 8   324424  00CL  small_airport                 Williams Ag Airport
# 9   322658  00CN       heliport     Kitchen Creek Helibase Heliport
# 10    6529  00CO         closed                          Cass Field
# 11    6531  00FA  small_airport                 Grass Patch Airport
# 12    6532  00FD       heliport                  Ringhaver Heliport
# ...

# %%
ap.shape
# Out:
# (56980, 18)

# %%
df.tail()
# Out:
#         DAY_OF_MONTH  DAY_OF_WEEK OP_UNIQUE_CARRIER  OP_CARRIER_AIRLINE_ID  \
# 583980            31            4                UA                  19977
# 583981            31            4                UA                  19977
# 583982            31            4                UA                  19977
# 583983            31            4                UA                  19977
# 583984            31            4                UA                  19977
#
#        OP_CARRIER TAIL_NUM  OP_CARRIER_FL_NUM  ORIGIN_AIRPORT_ID  \
# 583980         UA   N776UA                200              12016
# 583981         UA   N36280                174              12016
# 583982         UA   N36280                117              14955
# 583983         UA   N39726                105              14955
# 583984         UA   N39726                104              12016
#
#         ORIGIN_AIRPORT_SEQ_ID ORIGIN  ...  DEST  DEP_TIME DEP_DEL15  \
# ...

# %%
df.shape
# Out:
# (583985, 22)

# %%
df.isnull().sum()
# Out:
# DAY_OF_MONTH                  0
# DAY_OF_WEEK                   0
# OP_UNIQUE_CARRIER             0
# OP_CARRIER_AIRLINE_ID         0
# OP_CARRIER                    0
# TAIL_NUM                   2543
# OP_CARRIER_FL_NUM             0
# ORIGIN_AIRPORT_ID             0
# ORIGIN_AIRPORT_SEQ_ID         0
# ORIGIN                        0
# DEST_AIRPORT_ID               0
# DEST_AIRPORT_SEQ_ID           0
# DEST                          0
# DEP_TIME                  16352
# DEP_DEL15                 16355
# DEP_TIME_BLK                  0
# ARR_TIME                  17061
# ARR_DEL15                 18022
# CANCELLED                     0
# DIVERTED                      0
# DISTANCE                      0
# Unnamed: 21              583985
# dtype: int64

# %%
df.drop('Unnamed: 21', 1, inplace = True)

# %%
avg_dist = np.mean(df['DISTANCE'])

# %%
df[df['ARR_DEL15'].isnull() & df['ARR_TIME'].isnull()]
# Out:
#         DAY_OF_MONTH  DAY_OF_WEEK OP_UNIQUE_CARRIER  OP_CARRIER_AIRLINE_ID  \
# 397                1            2                AA                  19805
# 403                1            2                AA                  19805
# 971                1            2                OH                  20397
# 1973               1            2                EV                  20366
# 1975               1            2                EV                  20366
# ...              ...          ...               ...                    ...
# 583958            31            4                UA                  19977
# 583959            31            4                UA                  19977
# 583964            31            4                UA                  19977
# 583966            31            4                UA                  19977
# 583967            31            4                UA                  19977
#
#        OP_CARRIER TAIL_NUM  OP_CARRIER_FL_NUM  ORIGIN_AIRPORT_ID  \
# ...

# %%
df.dropna(axis=0, inplace=True)
df.shape
# Out:
# (565963, 21)

# %%
df.isnull().sum()
# Out:
# DAY_OF_MONTH             0
# DAY_OF_WEEK              0
# OP_UNIQUE_CARRIER        0
# OP_CARRIER_AIRLINE_ID    0
# OP_CARRIER               0
# TAIL_NUM                 0
# OP_CARRIER_FL_NUM        0
# ORIGIN_AIRPORT_ID        0
# ORIGIN_AIRPORT_SEQ_ID    0
# ORIGIN                   0
# DEST_AIRPORT_ID          0
# DEST_AIRPORT_SEQ_ID      0
# DEST                     0
# DEP_TIME                 0
# DEP_DEL15                0
# DEP_TIME_BLK             0
# ARR_TIME                 0
# ARR_DEL15                0
# CANCELLED                0
# DIVERTED                 0
# DISTANCE                 0
# dtype: int64

# %%
dow_df = df.groupby('DAY_OF_WEEK')

# %%
df.describe()
# Out:
#         DAY_OF_MONTH    DAY_OF_WEEK  OP_CARRIER_AIRLINE_ID  OP_CARRIER_FL_NUM  \
# count  565963.000000  565963.000000          565963.000000      565963.000000
# mean       15.782154       3.838159           19980.978304        2522.229453
# std         8.960357       1.919589             376.457094        1818.938051
# min         1.000000       1.000000           19393.000000           1.000000
# 25%         8.000000       2.000000           19790.000000         970.000000
# 50%        16.000000       4.000000           19977.000000        2098.000000
# 75%        24.000000       5.000000           20368.000000        3874.000000
# max        31.000000       7.000000           20452.000000        7439.000000
#
#        ORIGIN_AIRPORT_ID  ORIGIN_AIRPORT_SEQ_ID  DEST_AIRPORT_ID  \
# count      565963.000000           5.659630e+05    565963.000000
# mean        12656.397568           1.265644e+06     12655.895113
# std          1520.133210           1.520131e+05      1520.310647
# ...

# %%
df.head()
# Out:
#    DAY_OF_MONTH  DAY_OF_WEEK OP_UNIQUE_CARRIER  OP_CARRIER_AIRLINE_ID  \
# 0             1            2                9E                  20363
# 1             1            2                9E                  20363
# 2             1            2                9E                  20363
# 3             1            2                9E                  20363
# 4             1            2                9E                  20363
#
#   OP_CARRIER TAIL_NUM  OP_CARRIER_FL_NUM  ORIGIN_AIRPORT_ID  \
# 0         9E   N8688C               3280              11953
# 1         9E   N348PQ               3281              13487
# 2         9E   N8896A               3282              11433
# 3         9E   N8886A               3283              15249
# 4         9E   N8974C               3284              10397
#
#    ORIGIN_AIRPORT_SEQ_ID ORIGIN  ...  DEST_AIRPORT_SEQ_ID  DEST DEP_TIME  \
# 0                1195302    GNV  ...              1039707   ATL    601.0
# ...

# %%
df['DAY_OF_WEEK'].value_counts()
# Out:
# 4    96473
# 3    93343
# 2    89682
# 5    78654
# 1    76805
# 7    70860
# 6    60146
# Name: DAY_OF_WEEK, dtype: int64

# %%
plt.figure(figsize=(15,10))
sns.countplot(x="DAY_OF_WEEK", hue="DAY_OF_WEEK", data=df)
plt.legend(loc='upper right')

# %%
dow_dict = {1:'Monday', 2:'Tuesday', 3:'Wednesday', 4:'Thursday', 5:'Friday', 6:'Saturday', 7:'Sunday'}

df['DAY_NAME'] = df['DAY_OF_WEEK'].apply(lambda x: dow_dict[x])

# %%
df.head()
# Out:
#    DAY_OF_MONTH  DAY_OF_WEEK OP_UNIQUE_CARRIER  OP_CARRIER_AIRLINE_ID  \
# 0             1            2                9E                  20363
# 1             1            2                9E                  20363
# 2             1            2                9E                  20363
# 3             1            2                9E                  20363
# 4             1            2                9E                  20363
#
#   OP_CARRIER TAIL_NUM  OP_CARRIER_FL_NUM  ORIGIN_AIRPORT_ID  \
# 0         9E   N8688C               3280              11953
# 1         9E   N348PQ               3281              13487
# 2         9E   N8896A               3282              11433
# 3         9E   N8886A               3283              15249
# 4         9E   N8974C               3284              10397
#
#    ORIGIN_AIRPORT_SEQ_ID ORIGIN  ...  DEST  DEP_TIME DEP_DEL15  DEP_TIME_BLK  \
# 0                1195302    GNV  ...   ATL     601.0       0.0     0600-0659
# ...

# %%
plt.figure(figsize=(15,10))
sns.countplot(x="DAY_NAME", hue="DAY_NAME", data=df)
plt.legend(loc='upper right')

# %%
df['DAY_NAME'] = pd.Categorical(df['DAY_NAME'], ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday'])
df.sort_values(by='DAY_NAME')
# Out:
#         DAY_OF_MONTH  DAY_OF_WEEK OP_UNIQUE_CARRIER  OP_CARRIER_AIRLINE_ID  \
# 390865            21            1                OO                  20304
# 123145             7            1                OO                  20304
# 123144             7            1                OO                  20304
# 123143             7            1                OO                  20304
# 123142             7            1                OO                  20304
# ...              ...          ...               ...                    ...
# 109299             6            7                OO                  20304
# 109298             6            7                OO                  20304
# 109297             6            7                OO                  20304
# 109270             6            7                OO                  20304
# 100437             6            7                UA                  19977
#
#        OP_CARRIER TAIL_NUM  OP_CARRIER_FL_NUM  ORIGIN_AIRPORT_ID  \
# ...

# %%
plt.figure(figsize=(15,10))
sns.countplot(x="DAY_NAME", hue="DAY_NAME", data=df)
plt.legend(loc='upper right')

# %%
plt.figure(figsize=(15,13))
sns.countplot(x="DAY_OF_MONTH", hue="DAY_OF_MONTH", data=df)
plt.legend(loc='upper right')

# %%
df['DAY_OF_MONTH'].value_counts().sort_values(ascending=False)
# Out:
# 2     20170
# 7     19851
# 11    19827
# 25    19826
# 10    19756
# 17    19713
# 14    19661
# 18    19534
# 24    19503
# 4     19467
# 3     19341
# 6     19096
# 9     19045
# 21    18858
# 16    18756
# 8     18579
# 23    18458
# 28    18435
# 15    18382
# 27    18322
# 31    18160
# 1     17844
# 13    17779
# 29    17482
# 22    17395
# 30    16914
# 5     16643
# 20    15663
# 26    15178
# 12    14943
# 19    13382
# Name: DAY_OF_MONTH, dtype: int64

# %%
df['DEP_DEL15'].mean()
# Out:
# 0.17369510020973103

# %%
df.head()
# Out:
#    DAY_OF_MONTH  DAY_OF_WEEK OP_UNIQUE_CARRIER  OP_CARRIER_AIRLINE_ID  \
# 0             1            2                9E                  20363
# 1             1            2                9E                  20363
# 2             1            2                9E                  20363
# 3             1            2                9E                  20363
# 4             1            2                9E                  20363
#
#   OP_CARRIER TAIL_NUM  OP_CARRIER_FL_NUM  ORIGIN_AIRPORT_ID  \
# 0         9E   N8688C               3280              11953
# 1         9E   N348PQ               3281              13487
# 2         9E   N8896A               3282              11433
# 3         9E   N8886A               3283              15249
# 4         9E   N8974C               3284              10397
#
#    ORIGIN_AIRPORT_SEQ_ID ORIGIN  ...  DEST  DEP_TIME DEP_DEL15  DEP_TIME_BLK  \
# 0                1195302    GNV  ...   ATL     601.0       0.0     0600-0659
# ...

# %%
df['DEP_TIME_BLK'].head()
# Out:
# 0    0600-0659
# 1    1400-1459
# 2    1200-1259
# 3    1500-1559
# 4    1900-1959
# Name: DEP_TIME_BLK, dtype: object

# %%
for x in range(5):
    print (int(df['DEP_TIME_BLK'][x][:4]))
# Out:
# 600
# 1400
# 1200
# 1500
# 1900

# %%
p = pd.Period(df['DEP_TIME_BLK'][0][:4])
p.hour
# Out:
# 0

# %%
type(df['DEP_TIME_BLK'][0])
# Out:
# str

# %%
df['INT_HOUR'] = df['DEP_TIME_BLK'].apply(lambda x: int(x[:4]))

# %%
df.head()
# Out:
#    DAY_OF_MONTH  DAY_OF_WEEK OP_UNIQUE_CARRIER  OP_CARRIER_AIRLINE_ID  \
# 0             1            2                9E                  20363
# 1             1            2                9E                  20363
# 2             1            2                9E                  20363
# 3             1            2                9E                  20363
# 4             1            2                9E                  20363
#
#   OP_CARRIER TAIL_NUM  OP_CARRIER_FL_NUM  ORIGIN_AIRPORT_ID  \
# 0         9E   N8688C               3280              11953
# 1         9E   N348PQ               3281              13487
# 2         9E   N8896A               3282              11433
# 3         9E   N8886A               3283              15249
# 4         9E   N8974C               3284              10397
#
#    ORIGIN_AIRPORT_SEQ_ID ORIGIN  ...  DEP_TIME  DEP_DEL15 DEP_TIME_BLK  \
# 0                1195302    GNV  ...     601.0        0.0    0600-0659
# ...

# %%
def group_times(df, group_vals, label_names):
    df["DEP_TIME_BLK_CAT"]=pd.cut(df["INT_HOUR"], bins=group_vals, labels=label_names)
    return df

group_vals=[0, 400, 1030, 1400, 1800, 2000, 2359]
label_names=["Early Morning", "Morning", "Afternoon", "Midday", "Evening", "Night"]
df2=group_times(df, group_vals, label_names)

# %%
df2.head()
# Out:
#    DAY_OF_MONTH  DAY_OF_WEEK OP_UNIQUE_CARRIER  OP_CARRIER_AIRLINE_ID  \
# 0             1            2                9E                  20363
# 1             1            2                9E                  20363
# 2             1            2                9E                  20363
# 3             1            2                9E                  20363
# 4             1            2                9E                  20363
#
#   OP_CARRIER TAIL_NUM  OP_CARRIER_FL_NUM  ORIGIN_AIRPORT_ID  \
# 0         9E   N8688C               3280              11953
# 1         9E   N348PQ               3281              13487
# 2         9E   N8896A               3282              11433
# 3         9E   N8886A               3283              15249
# 4         9E   N8974C               3284              10397
#
#    ORIGIN_AIRPORT_SEQ_ID ORIGIN  ...  DEP_DEL15  DEP_TIME_BLK ARR_TIME  \
# 0                1195302    GNV  ...        0.0     0600-0659    722.0
# ...

# %%
df2[df2['DIVERTED'] > 0 ]
# Out:
# Empty DataFrame
# Columns: [DAY_OF_MONTH, DAY_OF_WEEK, OP_UNIQUE_CARRIER, OP_CARRIER_AIRLINE_ID, OP_CARRIER, TAIL_NUM, OP_CARRIER_FL_NUM, ORIGIN_AIRPORT_ID, ORIGIN_AIRPORT_SEQ_ID, ORIGIN, DEST_AIRPORT_ID, DEST_AIRPORT_SEQ_ID, DEST, DEP_TIME, DEP_DEL15, DEP_TIME_BLK, ARR_TIME, ARR_DEL15, CANCELLED, DIVERTED, DISTANCE, DAY_NAME, INT_HOUR, DEP_TIME_BLK_CAT]
# Index: []
#
# [0 rows x 24 columns]

# %%
plt.figure(figsize=(12,10))
sns.countplot(x='DEP_TIME_BLK_CAT', hue='DEP_TIME_BLK_CAT', data=df2)

# %%
df['ORIGIN'].value_counts().sort_values(ascending=True)
# Out:
# OGD        8
# ADK        9
# OWB        9
# OGS       10
# HGR       10
#        ...
# DEN    18220
# CLT    18772
# DFW    22705
# ORD    23336
# ATL    30783
# Name: ORIGIN, Length: 346, dtype: int64

# %%
df[df['ORIGIN']=='ATL'].DEP_TIME_BLK_CAT.value_counts()
# Out:
# Morning          8319
# Midday           7296
# Afternoon        6970
# Night            4258
# Evening          3821
# Early Morning     119
# Name: DEP_TIME_BLK_CAT, dtype: int64

# %%
type(df[df['OP_CARRIER_AIRLINE_ID']==20363])
# Out:
# pandas.core.frame.DataFrame

# %%
df[df['OP_CARRIER_AIRLINE_ID']==20363].TAIL_NUM.value_counts()
# Out:
# N8918B    182
# N8928A    176
# N8886A    167
# N921XJ    166
# N8896A    166
#          ...
# N918XJ     31
# N605LR     21
# N678CA     16
# N801AY     15
# N8847A      7
# Name: TAIL_NUM, Length: 154, dtype: int64

# %%
ap = pd.read_csv('airports.csv')

# %%
ap.shape
# Out:
# (56980, 18)

# %%
ap.head()
# Out:
#        id ident           type                                name  \
# 0    6523   00A       heliport                   Total Rf Heliport
# 1  323361  00AA  small_airport                Aero B Ranch Airport
# 2    6524  00AK  small_airport                        Lowell Field
# 3    6525  00AL  small_airport                        Epps Airpark
# 4    6526  00AR         closed  Newport Hospital & Clinic Heliport
#
#    latitude_deg  longitude_deg  elevation_ft continent iso_country iso_region  \
# 0     40.070801     -74.933601          11.0       NaN          US      US-PA
# 1     38.704022    -101.473911        3435.0       NaN          US      US-KS
# 2     59.949200    -151.695999         450.0       NaN          US      US-AK
# 3     34.864799     -86.770302         820.0       NaN          US      US-AL
# 4     35.608700     -91.254898         237.0       NaN          US      US-AR
#
#    municipality scheduled_service gps_code iata_code local_code home_link  \
# ...

# %%
df.head()
# Out:
#    DAY_OF_MONTH  DAY_OF_WEEK OP_UNIQUE_CARRIER  OP_CARRIER_AIRLINE_ID  \
# 0             1            2                9E                  20363
# 1             1            2                9E                  20363
# 2             1            2                9E                  20363
# 3             1            2                9E                  20363
# 4             1            2                9E                  20363
#
#   OP_CARRIER TAIL_NUM  OP_CARRIER_FL_NUM  ORIGIN_AIRPORT_ID  \
# 0         9E   N8688C               3280              11953
# 1         9E   N348PQ               3281              13487
# 2         9E   N8896A               3282              11433
# 3         9E   N8886A               3283              15249
# 4         9E   N8974C               3284              10397
#
#    ORIGIN_AIRPORT_SEQ_ID ORIGIN  ...  DEP_TIME_BLK  ARR_TIME ARR_DEL15  \
# 0                1195302    GNV  ...     0600-0659     722.0       0.0
# ...

# %%
df2.head()
# Out:
#    DAY_OF_MONTH  DAY_OF_WEEK OP_UNIQUE_CARRIER  OP_CARRIER_AIRLINE_ID  \
# 0             1            2                9E                  20363
# 1             1            2                9E                  20363
# 2             1            2                9E                  20363
# 3             1            2                9E                  20363
# 4             1            2                9E                  20363
#
#   OP_CARRIER TAIL_NUM  OP_CARRIER_FL_NUM  ORIGIN_AIRPORT_ID  \
# 0         9E   N8688C               3280              11953
# 1         9E   N348PQ               3281              13487
# 2         9E   N8896A               3282              11433
# 3         9E   N8886A               3283              15249
# 4         9E   N8974C               3284              10397
#
#    ORIGIN_AIRPORT_SEQ_ID ORIGIN  ...  DEP_TIME_BLK  ARR_TIME ARR_DEL15  \
# 0                1195302    GNV  ...     0600-0659     722.0       0.0
# ...

# %%
df['airport_names'] = 'NaN'

# %%
for x in df2['ORIGIN_AIRPORT_ID']: 
    print (df2[df2['ORIGIN_AIRPORT_ID']==x].airport_names)

# %%
for x in df2['ORIGIN_AIRPORT_ID']: 
    df2[df2['id']] (ap[ap['id']==x].name)
# Out:
# 5908    University of Florida Heliport
# Name: name, dtype: object
# 7550    Lasley Private Airport
# Name: name, dtype: object
# 5341    Andrews Airport
# Name: name, dtype: object
# 9464    Dillenburg's Airport
# Name: name, dtype: object
# 4199    The Buttes in Tempe Heliport
# Name: name, dtype: object
# 5165    Gtr Green River Intergalactic Spaceport Airport
# Name: name, dtype: object
# 6435    Kent's Flying Service Airport
# Name: name, dtype: object
# 6970    Rose Nr 3 Heliport
# Name: name, dtype: object
# 6438    Shell Morgan City Heliport
# Name: name, dtype: object
# 4199    The Buttes in Tempe Heliport
# Name: name, dtype: object
# 4505    North Omaha Airport
# Name: name, dtype: object
# 4706    Tesmer Airport
# Name: name, dtype: object
# 5341    Andrews Airport
# Name: name, dtype: object
# 7550    Lasley Private Airport
# Name: name, dtype: object
# 8231    Baptist Medical Center Heliport
# Name: name, dtype: object
# 6466    Marble Head Farm Airport
# ...

# %%
for air_id in df2['ORIGIN_AIRPORT_ID']:
    df2[df2['ORIGIN_AIRPORT_ID']==air_id].airport_names = ap[ap['id']==air_id].name

# %%
def add_col(df1, df2): 
    for air_id in df2['ORIGIN_AIRPORT_ID']:
        print (df2['ORIGIN_AIRPORT_ID'][:5])
        #print (df2[df2['ORIGIN_AIRPORT_ID']==air_id].airport_names)
        #df2[df2['ORIGIN_AIRPORT_ID']==air_id].airport_names = ap[ap['id']==air_id].name
    #return df2

# %%
add_col(df2, ap)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2896             try:
# -> 2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'ORIGIN_AIRPORT_ID'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
df3 = add_col(df2, ap)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2896             try:
# -> 2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'ORIGIN_AIRPORT_ID'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# ...
